# %%
from solar_model import run_pvsam_and_export_ac_outputs

res = run_pvsam_and_export_ac_outputs(
    print_summary=True,
)

# print(res["csv_path"], res["n_timesteps"])
# Out:
# [INFO] Reading JSON from: C:\Users\ardia\OneDrive - KTH\0. Thesis\project_oskarshamn_harbour\data\Json_pySAM\untitled_pvsamv1.json
# [INFO] Wrote 219000 timesteps to: C:\Users\ardia\OneDrive - KTH\0. Thesis\project_oskarshamn_harbour\outputs\pvsam_ac_outputs.csv
# [INFO] Annual AC gross (kWh): 175,926

# %%
from plot_res import plot_yearly_production

df, annual_kwh = plot_yearly_production(
    csv_path=res["csv_path"],
    power_col="ac_gross_kw",
    timestep_hours=1.0
)
# Out:
# Annual production = 4,132,340.26 kWh
# Annual production = 4,132.34 MWh
